# %% [markdown]
# ## Aadhaar Update Behaviour
#
# Aadhaar updates reflect lifecycle events such as aging, mobility, and corrections.
# This section analyzes biometric and demographic update volumes across states.

# %%
bio = pd.read_csv("../outputs/tables/biometric_updates_by_state.csv")
demo = pd.read_csv("../outputs/tables/demographic_updates_by_state.csv")

bio.head(), demo.head()

# %% [markdown]
# ### Interpretation
#
# High update volumes suggest sustained interaction with Aadhaar services.
# Such regions may require additional infrastructure and staffing to maintain service
# quality.
