# %% [markdown]
# ## Data Cleaning and Preprocessing
#
# The UIDAI datasets were provided in multiple CSV files corresponding to:
# - Aadhaar enrolment
# - Biometric updates
# - Demographic updates
#
# Key preprocessing steps included:
# - Standardizing column names
# - Removing inconsistencies
# - Ensuring numerical fields are valid
# - Aggregating records at the state level

# %%
df.columns = df.columns.str.lower().str.strip()
df.info()

# %% [markdown]
# ## Handling Missing Values
#
# Missing values were minimal due to aggregation. Any incomplete rows were excluded
# to ensure consistency in comparative analysis.

# %%
df.isnull().sum()
